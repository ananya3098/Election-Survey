# %%
import pandas as pd

# %%
#Load the dataset into a pandas dataframe. Name the variable as “survey”.
survey= pd.read_csv(r"C:\Users\ANANYA\OneDrive\Desktop\Survey Dataset - Technical Interview.csv")

# %%
survey
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %%
# How many samples were collected on each day?
survey.collection_date.value_counts()
# Out:
# 5-24-2017    1479
# 5-25-2017     998
# 5-28-2017     761
# 5-27-2017     665
# 5-29-2017     620
# 6-1-2017      607
# 5-26-2017     598
# 5-30-2017     582
# 5-31-2017     557
# Name: collection_date, dtype: int64

# %%
#What proportion of the total respondents were aged less than 45?
survey.age<45
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 survey.age<45
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:5623, in Series._cmp_method(self, other, op)
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# ...

# %%
survey.age.dtype
# Out:
# dtype('O')

# %%
survey.age.unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', '24ko', '56', '50', '55', '54', '62', '60', '59',
#        '47', '61', '52', '66', '57', '67', '65', '71', '63', '64', '68',
#        '69', '99', '72', '75', '76'], dtype=object)

# %%
survey.age.replace({'24ko':24},inplace=True) #Replacing 24ko with 24

# %%
survey.age.unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', 24, '56', '50', '55', '54', '62', '60', '59',
#        '47', '61', '52', '66', '57', '67', '65', '71', '63', '64', '68',
#        '69', '99', '72', '75', '76'], dtype=object)

# %%
survey.age=survey.age.astype(int)  #Chaning age to int type

# %%
survey.age.dtype
# Out:
# dtype('int32')

# %%
survey[survey.age<45]
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %%
#proportion of respondents
(6399/6867)*100
# Out:
# 93.18479685452162

# %%
#create a new column in the dataframe “age_group”. This column should contain the age group the respondent belongs to. 
#The age groups are 18-25, 25-40, 40-55 and 55+. 

data=survey.copy()

# %%
data.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
data.insert(10,'age_group_',survey.age)

# %%
data.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age  age_group_  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26          26
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34          34
#
#   gender  assembly_no category    weight
# 0   Male          211      Gen  0.346969
# 1   Male          189       BC  0.603419

# %%
data1=data[(data.age_group_>18)&(data.age_group_<25)]

# %%
data1
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6858         6859        6-1-2017       Rural                Graduate
# 6859         6860        6-1-2017       Urban       Post - Graduation
# 6861         6862        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
#
#                    income    Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
data1['age_group_'] = '18-25'
# Out:
# C:\Users\ANANYA\AppData\Local\Temp\ipykernel_10676\863906948.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['age_group_'] = '18-25'

# %%
data1
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6858         6859        6-1-2017       Rural                Graduate
# 6859         6860        6-1-2017       Urban       Post - Graduation
# 6861         6862        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
#
#                    income    Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
data2=data[(data.age>=25)&(data.age<40)]
data2
# Out:
#       response_id collection_date urban_rural  education               income  \
# 0               1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1               2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2               3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3               4       5-24-2017       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 5               6       5-24-2017       Urban   Graduate  ₹ 20,000 - ₹ 30,000
# ...           ...             ...         ...        ...                  ...
# 6855         6856        6-1-2017       Rural  12th Pass   ₹ 5,000 - ₹ 10,000
# 6860         6861        6-1-2017       Rural   Graduate    BPL/Below ₹ 5,000
# 6862         6863        6-1-2017       Rural  10th Pass    BPL/Below ₹ 5,000
# 6863         6864        6-1-2017       Rural   Graduate    BPL/Below ₹ 5,000
# 6866         6867        6-1-2017       Rural  10th Pass   ₹ 5,000 - ₹ 10,000
#
# ...

# %%
data2.age_group_='25-40'
# Out:
# C:\Users\ANANYA\AppData\Local\Temp\ipykernel_10676\2862977017.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.age_group_='25-40'

# %%
data3=data[(data.age>=40)&(data.age<55)]
data3
# Out:
#       response_id collection_date urban_rural          education  \
# 11             12       5-24-2017       Urban           Graduate
# 12             13       5-24-2017       Urban  Post - Graduation
# 28             29       5-24-2017       Rural           Graduate
# 30             31       5-24-2017       Urban           Graduate
# 33             34       5-24-2017       Urban           Graduate
# ...           ...             ...         ...                ...
# 6816         6817        6-1-2017       Rural          12th Pass
# 6819         6820        6-1-2017       Urban          12th Pass
# 6829         6830        6-1-2017       Urban           Graduate
# 6840         6841        6-1-2017       Rural           Graduate
# 6856         6857        6-1-2017       Rural  Post - Graduation
#
#                    income   Vote_Now Past_Vote        CM_satisfaction  \
# 11    ₹ 10,000 - ₹ 20,000        LJP     JD(U)     Somewhat Satisfied
# ...

# %%
data3.age_group_='40-55'
# Out:
# C:\Users\ANANYA\AppData\Local\Temp\ipykernel_10676\905445340.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3.age_group_='40-55'

# %%
data3

# %%
data4=data[data.age>55]
data4
# Out:
#       response_id collection_date urban_rural               education  \
# 69             70       5-24-2017       Rural                Graduate
# 74             75       5-24-2017       Urban                Graduate
# 121           122       5-24-2017       Rural                Graduate
# 126           127       5-24-2017       Urban                Graduate
# 277           278       5-24-2017       Urban       Post - Graduation
# ...           ...             ...         ...                     ...
# 6579         6580       5-29-2017       Rural                Graduate
# 6702         6703       5-31-2017       Urban  Professional Education
# 6720         6721       5-31-2017       Rural                Graduate
# 6787         6788        6-1-2017       Rural               10th Pass
# 6851         6852        6-1-2017       Urban                Graduate
#
#                      income Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
data4.age_group_='55+'
data4
# Out:
# C:\Users\ANANYA\AppData\Local\Temp\ipykernel_10676\1004848790.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data4.age_group_='55+'
#       response_id collection_date urban_rural               education  \
# 69             70       5-24-2017       Rural                Graduate
# 74             75       5-24-2017       Urban                Graduate
# 121           122       5-24-2017       Rural                Graduate
# 126           127       5-24-2017       Urban                Graduate
# 277           278       5-24-2017       Urban       Post - Graduation
# ...           ...             ...         ...                     ...
# 6579         6580       5-29-2017       Rural                Graduate
# ...

# %%
data=pd.concat([data1,data2,data3,data4])

# %%
data #dataframe with different age categories
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6579         6580       5-29-2017       Rural                Graduate
# 6702         6703       5-31-2017       Urban  Professional Education
# 6720         6721       5-31-2017       Rural                Graduate
# 6787         6788        6-1-2017       Rural               10th Pass
# 6851         6852        6-1-2017       Urban                Graduate
#
#                    income Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
#How many samples were collected for each age-group? Which age-group had the most samples?
data.age_group_.value_counts()
# Out:
# 25-40    3844
# 18-25    1969
# 40-55     801
# 55+       108
# Name: age_group_, dtype: int64

# %%
#What proportion of the respondents had opted for the RJD party in both the Vote_Now and the Past_Vote questions?

vote=survey[(survey.Vote_Now=='RJD')&(survey.Past_Vote=='RJD')]
vote
# Out:
#       response_id collection_date urban_rural          education  \
# 3               4       5-24-2017       Urban           Graduate
# 9              10       5-24-2017       Urban          12th Pass
# 16             17       5-24-2017       Rural  Post - Graduation
# 19             20       5-24-2017       Rural           Graduate
# 21             22       5-24-2017       Rural           Graduate
# ...           ...             ...         ...                ...
# 6846         6847        6-1-2017       Rural  Post - Graduation
# 6848         6849        6-1-2017       Rural  Post - Graduation
# 6858         6859        6-1-2017       Rural           Graduate
# 6860         6861        6-1-2017       Rural           Graduate
# 6863         6864        6-1-2017       Rural           Graduate
#
#                    income Vote_Now Past_Vote     CM_satisfaction  \
# 3     ₹ 10,000 - ₹ 20,000      RJD       RJD  Fully Dissatisfied
# ...

# %%
#proportion
(811/6867)*100
# Out:
# 11.810106305519149

# %%
survey.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
#For each day of sample collection, determine the proportion of respondents who were fully satisfied with 
#the performance of the CM. 


survey.collection_date.unique()
# Out:
# array(['5-24-2017', '5-25-2017', '5-26-2017', '5-27-2017', '5-28-2017',
#        '5-29-2017', '5-30-2017', '5-31-2017', '6-1-2017'], dtype=object)

# %%
survey.CM_satisfaction.unique()
# Out:
# array(['Fully Dissatisfied', 'Somewhat Satisfied', 'Fully Satisfied',
#        'Somewhat Dissatisfied', 'Can’t say'], dtype=object)

# %%
cm=survey[survey.CM_satisfaction=='Fully satisfied']
# Out:
# Empty DataFrame
# Columns: [response_id, collection_date, urban_rural, education, income, Vote_Now, Past_Vote, CM_satisfaction, MLA_satisfaction, age, gender, assembly_no, category, weight]
# Index: []

# %%
cm.collection_date.value_counts()
# Out:
# Series([], Name: collection_date, dtype: int64)

# %%
#create a day-wise proportion of respondents that opted fully dissatisfied with their MLA. 
#Create a line plot of the result with date on x-axis and proportions on the y-axis.

MLA=survey[survey.MLA_satisfaction=='Fully Dissatisfied']
MLA
# Out:
#       response_id collection_date urban_rural  education               income  \
# 0               1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1               2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 5               6       5-24-2017       Urban   Graduate  ₹ 20,000 - ₹ 30,000
# 6               7       5-24-2017       Urban   Graduate    BPL/Below ₹ 5,000
# 8               9       5-24-2017       Urban  12th Pass    BPL/Below ₹ 5,000
# ...           ...             ...         ...        ...                  ...
# 6855         6856        6-1-2017       Rural  12th Pass   ₹ 5,000 - ₹ 10,000
# 6857         6858        6-1-2017       Rural  12th Pass    BPL/Below ₹ 5,000
# 6862         6863        6-1-2017       Rural  10th Pass    BPL/Below ₹ 5,000
# 6863         6864        6-1-2017       Rural   Graduate    BPL/Below ₹ 5,000
# 6864         6865        6-1-2017       Urban   Graduate   ₹ 5,000 - ₹ 10,000
#
# ...

# %%
a=MLA.collection_date.value_counts()
a
# Out:
# 5-24-2017    887
# 5-25-2017    630
# 5-28-2017    462
# 5-27-2017    403
# 6-1-2017     385
# 5-30-2017    361
# 5-26-2017    353
# 5-29-2017    350
# 5-31-2017    321
# Name: collection_date, dtype: int64

# %%
b=survey.collection_date.value_counts()
b
# Out:
# 5-24-2017    1479
# 5-25-2017     998
# 5-28-2017     761
# 5-27-2017     665
# 5-29-2017     620
# 6-1-2017      607
# 5-26-2017     598
# 5-30-2017     582
# 5-31-2017     557
# Name: collection_date, dtype: int64

# %%
z=(a/b)*100
z
# Out:
# 5-24-2017    59.972955
# 5-25-2017    63.126253
# 5-26-2017    59.030100
# 5-27-2017    60.601504
# 5-28-2017    60.709593
# 5-29-2017    56.451613
# 5-30-2017    62.027491
# 5-31-2017    57.630162
# 6-1-2017     63.426689
# Name: collection_date, dtype: float64

# %%
type(z)
# Out:
# pandas.core.series.Series

# %%
p=pd.DataFrame(z)  #converting series to dataframe for plotting

# %%
type(p)
# Out:
# pandas.core.frame.DataFrame

# %%
p
# Out:
#            collection_date
# 5-24-2017        59.972955
# 5-25-2017        63.126253
# 5-26-2017        59.030100
# 5-27-2017        60.601504
# 5-28-2017        60.709593
# 5-29-2017        56.451613
# 5-30-2017        62.027491
# 5-31-2017        57.630162
# 6-1-2017         63.426689

# %%
p.plot(kind='line',figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
#Create a pivot-table (or crosstab) with index as Past_Vote, Column as Vote_Now and cell values as the count of samples.

survey.pivot_table(index = 'Past_Vote', columns = 'Vote_Now', values = 'response_id', aggfunc = 'count')
# Out:
# Vote_Now      AAP  AIMIM     BJP  BSP  HAM   INC  JAP(L)  JD(U)   LJP  \
# Past_Vote
# BJP           7.0    1.0  1630.0  3.0  5.0  42.0   101.0  110.0  44.0
# BSP           NaN    1.0     2.0  5.0  NaN   1.0     NaN    NaN   NaN
# Did not vote  8.0    5.0   231.0  2.0  1.0  22.0    41.0   69.0  10.0
# HAM           2.0    NaN    25.0  NaN  1.0   NaN     3.0    2.0   2.0
# INC           NaN    6.0     6.0  NaN  NaN  57.0    10.0    9.0   NaN
# JAP(L)        NaN    NaN     4.0  NaN  NaN   NaN    35.0    NaN   NaN
# JD(U)         6.0   10.0   254.0  2.0  2.0  45.0    72.0  279.0  29.0
# LJP           NaN    NaN    76.0  1.0  NaN   4.0     3.0    6.0   9.0
# Left Front    NaN    1.0     2.0  NaN  NaN   1.0     NaN    NaN   NaN
# NOTA          NaN    1.0    29.0  1.0  NaN   9.0     7.0    7.0   3.0
# Others        1.0    5.0    45.0  1.0  1.0   4.0     7.0    4.0   1.0
# RJD           3.0    7.0    46.0  NaN  1.0  31.0    31.0   39.0   4.0
# ...

# %%
#Repeat the above question with the cell values as the sum of “weight”.

survey.pivot_table(index='Past_Vote',columns='Vote_Now',values='weight',aggfunc='sum')

# %%
#Create a dataframe by performing a group by over age_group 
#and finding the count of total samples for each age_group that opted for the JD(U) party in Vote_Now.

data.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
# 8            9       5-24-2017       Urban  12th Pass    BPL/Below ₹ 5,000
#
#   Vote_Now     Past_Vote  CM_satisfaction    MLA_satisfaction  age age_group_  \
# 4    JD(U)  Did not vote  Fully Satisfied     Fully Satisfied   22      18-25
# 8      BJP           BJP  Fully Satisfied  Fully Dissatisfied   23      18-25
#
#   gender  assembly_no category    weight
# 4   Male          176       BC  0.333505
# 8   Male          181      Gen  0.226477

# %%
survey
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %%
data
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6579         6580       5-29-2017       Rural                Graduate
# 6702         6703       5-31-2017       Urban  Professional Education
# 6720         6721       5-31-2017       Rural                Graduate
# 6787         6788        6-1-2017       Rural               10th Pass
# 6851         6852        6-1-2017       Urban                Graduate
#
#                    income Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
#Create a dataframe by performing a group by over age_group 
#and finding the count of total samples for each age_group that opted for the JD(U) party in Vote_Now.

data.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
# 8            9       5-24-2017       Urban  12th Pass    BPL/Below ₹ 5,000
#
#   Vote_Now     Past_Vote  CM_satisfaction    MLA_satisfaction  age age_group_  \
# 4    JD(U)  Did not vote  Fully Satisfied     Fully Satisfied   22      18-25
# 8      BJP           BJP  Fully Satisfied  Fully Dissatisfied   23      18-25
#
#   gender  assembly_no category    weight
# 4   Male          176       BC  0.333505
# 8   Male          181      Gen  0.226477

# %%
data.groupby('age_group_').count()
# Out:
#             response_id  collection_date  urban_rural  education  income  \
# age_group_
# 18-25              1969             1969         1969       1969    1969
# 25-40              3844             3844         3844       3844    3844
# 40-55               801              801          801        801     801
# 55+                 108              108          108        108     108
#
#             Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction   age  \
# age_group_
# 18-25           1969       1969             1969              1969  1969
# 25-40           3844       3844             3844              3844  3844
# 40-55            801        801              801               801   801
# 55+              108        108              108               108   108
#
#             gender  assembly_no  category  weight
# age_group_
# 18-25         1969         1969      1969    1969
# 25-40         3844         3844      3844    3844
# ...

# %%
df=data.groupby('age_group_').count()

# %%
df2= data[data.Vote_Now=='JD(U)']
df2
# Out:
#       response_id collection_date urban_rural          education  \
# 4               5       5-24-2017       Rural           Graduate
# 67             68       5-24-2017       Urban          12th Pass
# 90             91       5-24-2017       Rural           Graduate
# 102           103       5-24-2017       Rural           Graduate
# 123           124       5-24-2017       Rural  Post - Graduation
# ...           ...             ...         ...                ...
# 1572         1573       5-25-2017       Urban  Post - Graduation
# 5248         5249       5-24-2017       Urban  Post - Graduation
# 5956         5957        6-1-2017       Urban          12th Pass
# 6341         6342       5-26-2017       Rural  Post - Graduation
# 6787         6788        6-1-2017       Rural          10th Pass
#
#                      income Vote_Now     Past_Vote     CM_satisfaction  \
# 4       ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote     Fully Satisfied
# ...

# %%
df2.groupby('age_group_').count()
# Out:
#             response_id  collection_date  urban_rural  education  income  \
# age_group_
# 18-25               164              164          164        164     164
# 25-40               264              264          264        264     264
# 40-55                68               68           68         68      68
# 55+                  10               10           10         10      10
#
#             Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction  age  \
# age_group_
# 18-25            164        164              164               164  164
# 25-40            264        264              264               264  264
# 40-55             68         68               68                68   68
# 55+               10         10               10                10   10
#
#             gender  assembly_no  category  weight
# age_group_
# 18-25          164          164       164     164
# 25-40          264          264       264     264
# ...
